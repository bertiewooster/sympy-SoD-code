# %%
from sympy import symbols, reduce_inequalities, cos
x = symbols('x')
reduce_inequalities([cos(x) - x > 0, x > 0], x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sympy/polys/polyutils.py in _parallel_dict_from_expr_if_gens(exprs, opt)
#     210
# --> 211                         monom[indices[base]] = exp
#     212                     except KeyError:
#
# KeyError: cos(_x)
#
# During handling of the above exception, another exception occurred:
#
# PolynomialError                           Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/sympy/solvers/inequalities.py in _solve_inequality(ie, s, linear)
#     827     try:
# --> 828         p = Poly(expr, s)
#     829         if p.degree() == 0:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/sympy/polys/polytools.py in __new__(cls, rep, *gens, **args)
#     163             else:
# --> 164                 return cls._from_expr(rep, opt)
#     165
#
# ...
